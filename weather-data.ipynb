# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import os

# %matplotlib inline

# %%
data = pd.read_csv('data/merged-2021.csv', parse_dates=['DATE'], encoding_errors='ignore', index_col=None, header=0)
# Out:
# /var/folders/g7/8crg6v9j4pxf3v63yzxxst4c0000gn/T/ipykernel_29953/3103408674.py:1: DtypeWarning: Columns (0,6,8,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data/merged-2021.csv', parse_dates=['DATE'], encoding_errors='ignore', index_col=None, header=0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65982063 entries, 0 to 65982062
# Data columns (total 19 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   STATION      object
#  1   DATE         datetime64[ns]
#  2   SOURCE       int64
#  3   LATITUDE     float64
#  4   LONGITUDE    float64
#  5   ELEVATION    float64
#  6   NAME         object
#  7   REPORT_TYPE  object
#  8   CALL_SIGN    object
#  9   SLP          object
#  10  REM          object
#  11  VIS_METERS   int64
#  12  VIS_V        object
#  13  WND_ANGLE    int64
#  14  WND_TYPE     object
#  15  WND_SPEED    int64
#  16  CIG_HEIGHT   int64
#  17  TMP_DEG_C    int64
#  18  DEW_DEG_C    int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(8)
# memory usage: 9.3+ GB

# %%
data.head()
# Out:
#       STATION                DATE  SOURCE   LATITUDE  LONGITUDE  ELEVATION  \
# 0  1001499999 2021-01-01 13:50:00       4  59.791925    5.34085      48.76
# 1  1001499999 2021-01-01 14:20:00       4  59.791925    5.34085      48.76
# 2  1001499999 2021-01-01 14:50:00       4  59.791925    5.34085      48.76
# 3  1001499999 2021-01-01 15:20:00       4  59.791925    5.34085      48.76
# 4  1001499999 2021-01-01 15:50:00       4  59.791925    5.34085      48.76
#
#              NAME REPORT_TYPE CALL_SIGN      SLP  \
# 0  SORSTOKKEN, NO       FM-15     99999  99999,9
# 1  SORSTOKKEN, NO       FM-15     99999  99999,9
# 2  SORSTOKKEN, NO       FM-15     99999  99999,9
# 3  SORSTOKKEN, NO       FM-15     99999  99999,9
# 4  SORSTOKKEN, NO       FM-15     99999  99999,9
#
#                                                  REM  VIS_METERS VIS_V  \
# 0  MET046METAR ENSO 011350Z 11005KT CAVOK 02/M00 ...        9900     9
# 1  MET046METAR ENSO 011420Z 11005KT CAVOK 02/M01 ...        9900     9
# ...

# %%
daily_average = data.resample('d', on='DATE').mean().dropna(how='all')
